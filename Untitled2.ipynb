# %%
#  1-10 RANGE TRAINING
import os
import json
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Input, AveragePooling2D, MaxPooling2D,Conv2D,Add, Dense, Flatten, Dropout, GlobalAveragePooling2D, Multiply, BatchNormalization, TimeDistributed, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam,RMSprop,SGD
from tensorflow.keras.applications import VGG16,ResNet50
from tensorflow.keras.metrics import AUC, MeanAbsoluteError
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import matplotlib.pyplot as plt
from tensorflow.keras.layers import UpSampling2D, Cropping2D
#import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import joblib
#from keras.applications import VGG19
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Conv2DTranspose
# Assuming each image is 256x256 pixels with 3 color channels (RGB)
input_shape = (256, 256, 3)
num_outputs = 5  # 1 for the number of axes + 5 for the attribute values

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Path to the dataset and metadata file
# Define dataset path
dataset_path = r"extracted_data/FinalDatasetwithrangefix"
dataset_path2 = r"extracted_data/radarcharts_geridvaluesnofilllineentity2"
dataset_path3 = r"extracted_data/radarchart_with_linestar2"
dataset_path4 = r"extracted_data/radarcharts_equilateralpygal"
dataset_path5 = r"extracted_data/radarcharts_equilateral"
# Construct metadata path using os.path.join
metadata_path = os.path.join(dataset_path, "metadata.json")
metadata_path2 = os.path.join(dataset_path2, "metadata.json")
metadata_path3 = os.path.join(dataset_path3, "metadata.json")
metadata_path4 = os.path.join(dataset_path4, "metadata.json")
metadata_path5 = os.path.join(dataset_path5, "metadata.json")
# Load metadata
with open(metadata_path, 'r') as json_file:
    metadata = json.load(json_file)['data']
with open(metadata_path2, 'r') as json_file:
    metadata2 = json.load(json_file)['data']
with open(metadata_path3, 'r') as json_file:
    metadata3 = json.load(json_file)['data']
with open(metadata_path4, 'r') as json_file:
    metadata4 = json.load(json_file)['data']
with open(metadata_path5, 'r') as json_file:
    metadata5 = json.load(json_file)['data']
# Initialize lists to store data and labels
data = []
labels = []


for item in metadata5:
    image_name = item['Image Name']
    image_path = os.path.join(dataset_path5, image_name)
    image = load_img(image_path, target_size=(256, 256))
    image = img_to_array(image)
    image /= 255.0  # Normalize to [0, 1]
    # Convert image data to uint8
    image = image.astype(np.uint8)
    data.append(image)

    # Determine the number of axes
    num_axes = len(item['Attribute Data'])

    attribute_values = [attr['Value'] for attr in item['Attribute Data']]

    label = attribute_values + [0] * (5 - num_axes)
    labels.append(label)
# Load dataset and preprocess labels
for item in metadata:
    image_name = item['Image Name']
    image_path = os.path.join(dataset_path, image_name)
    image = load_img(image_path, target_size=(256, 256))
    image = img_to_array(image)
    #image /= 255.0  # Normalize to [0, 1]
    # Convert image data to uint8
    image = image.astype(np.uint8)
    data.append(image)

    # Determine the number of axes
    num_axes = len(item['Attribute Data'])

    attribute_values = [attr['Value'] for attr in item['Attribute Data']]

    label = attribute_values + [0] * (5 - num_axes)
    labels.append(label)
    # Load dataset and preprocess labels
for item in metadata2:
    image_name = item['Image Name']
    image_path = os.path.join(dataset_path2, image_name)
    image = load_img(image_path, target_size=(256, 256))
    image = img_to_array(image)
    #image /= 255.0  # Normalize to [0, 1]
    # Convert image data to uint8
    image = image.astype(np.uint8)
    data.append(image)

    # Determine the number of axes
    num_axes = len(item['Attribute Data'])

    attribute_values = [attr['Value'] for attr in item['Attribute Data']]

    label = attribute_values + [0] * (5 - num_axes)
    labels.append(label)
    # Load dataset and preprocess labels
for item in metadata3:
    image_name = item['Image Name']
    image_path = os.path.join(dataset_path3, image_name)
    image = load_img(image_path, target_size=(256, 256))
    image = img_to_array(image)
    #image /= 255.0  # Normalize to [0, 1]
    # Convert image data to uint8
    image = image.astype(np.uint8)
    data.append(image)

    # Determine the number of axes
    num_axes = len(item['Attribute Data'])

    attribute_values = [attr['Value'] for attr in item['Attribute Data']]

    label = attribute_values + [0] * (5 - num_axes)
    labels.append(label)
    
for item in metadata4:
    image_name = item['Image Name']
    image_path = os.path.join(dataset_path4, image_name)
    image = load_img(image_path, target_size=(256, 256))
    image = img_to_array(image)
    #image /= 255.0  # Normalize to [0, 1]
    # Convert image data to uint8
    image = image.astype(np.uint8)
    data.append(image)

    # Determine the number of axes
    num_axes = len(item['Attribute Data'])

    attribute_values = [attr['Value'] for attr in item['Attribute Data']]

    label = attribute_values + [0] * (5 - num_axes)
    labels.append(label)
    
for item in metadata5:
    image_name = item['Image Name']
    image_path = os.path.join(dataset_path5, image_name)
    image = load_img(image_path, target_size=(256, 256))
    image = img_to_array(image)
    image /= 255.0  # Normalize to [0, 1]
    # Convert image data to uint8
    image = image.astype(np.uint8)
    data.append(image)

    # Determine the number of axes
    num_axes = len(item['Attribute Data'])

    attribute_values = [attr['Value'] for attr in item['Attribute Data']]

    label = attribute_values + [0] * (5 - num_axes)
    labels.append(label)
#print(labels)
# Convert lists to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Split the dataset into training, validation, and testing sets
x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.67, random_state=42)

# Check the length of data and labels
print(f"Length of data: {len(data)}")
print(f"Length of labels: {len(labels)}")  # Corrected from preprocessed_labels to labels
# Check the shapes of the splits
print(f"Training data shape: {x_train.shape}")
print(f"Testing data shape: {x_test.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Testing labels shape: {y_test.shape}")

def create_attention_module(feature_map, input_channels, ratio=8):
    squeeze = GlobalAveragePooling2D()(feature_map)
    excitation = Dense(units=input_channels // ratio, activation='relu')(squeeze)
    excitation = Dense(units=input_channels, activation='sigmoid')(excitation)
    excitation = tf.reshape(excitation, [-1, 1, 1, input_channels])

    # Reduce the number of channels in excitation tensor
    #excitation = Conv2D(input_channels, kernel_size=(1, 1), strides=(1, 1), padding='same')(excitation)

    # Scale the input feature map
    scale = Multiply()([feature_map, excitation])

    return scale


def build_cnn_with_attention(input_shape, num_outputs):
    # Load the base model
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the layers of the base_model
    base_model.trainable = False
   
    # Apply attention module to the last convolutional feature maps
    #last_conv_layer = base_model.get_layer('conv5_block3_out').output
    #print(last_conv_layer.shape)
    # Upsample the smaller feature map to match the shape of last_conv_layer
    #upsampled_layer = UpSampling2D(size=(2, 2))(last_conv_layer)
    #print(upsampled_layer.shape)
    #conv_layer2 = Conv2D(2048, (3, 3), activation='relu')(last_conv_layer)
    #conv_layer2 =  MaxPooling2D((2, 2), padding='same')(conv_layer2)
    # Upsample conv_layer2 to match the spatial dimensions of last_conv_layer
    #conv_layer3 = Conv2DTranspose(256, (3, 3), activation='relu', padding='same')(conv_layer2)
    #conv_layer3 = Conv2D(2048, (3, 3), activation='relu', padding='same')(conv_layer3)  # Match channel dimension
       # Apply attention module to the last convolutional feature maps
    last_conv_layer = base_model.get_layer('conv5_block3_out').output
    print(last_conv_layer.shape)
    # Upsample the smaller feature map to match the shape of last_conv_layer
    #upsampled_layer = UpSampling2D(size=(2, 2))(last_conv_layer)
    #print(upsampled_layer.shape)
    # Add convolutional layer to match the desired shape
    conv_layer = Conv2D(2048, (1, 1), activation='relu', padding='same')(last_conv_layer)
    print(conv_layer.shape)
    attention_layer = create_attention_module(conv_layer  , input_channels=2048)
    # Residual connection
    residual_layer = Add()([last_conv_layer , attention_layer])
    
    #residual_layer = Add()([conv_layer2, attention_layer])

    # Continue from the residual layer
    gap_layer = GlobalAveragePooling2D()(residual_layer)
    
    # Apply BatchNormalization before Dropout
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(gap_layer)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    outputs = Dense(num_outputs)(x)  # Assuming a regression task

    # Creating the full model
    model = Model(inputs=base_model.input, outputs=outputs)

    # Compile the model
    model.compile(optimizer= Adam(learning_rate=0.001),
                  loss='mse',  # Use Mean Squared Error for regression
                  metrics=[tf.keras.metrics.MeanAbsoluteError()])  # Use MAE for evaluation

    return model


# Assuming each image is 256x256 pixels with 3 color channels (RGB)
input_shape = (256, 256, 3)
num_outputs = 5  # 1 for the number of axes + 5 for the attribute values

# Build the model
cnn_model = build_cnn_with_attention(input_shape, num_outputs)

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
model_checkpoint = ModelCheckpoint('best_model_datavalue.h5', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.006)
tensorboard = TensorBoard(log_dir='./logs')  # Assuming TensorBoard logs are stored in ./logs

# Summary of the model
cnn_model.summary()

# Fit the model with these variables for the corresponding outputs
history = cnn_model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=100,
    batch_size=16,
    callbacks=[early_stopping, model_checkpoint, reduce_lr, tensorboard]
)

# Load best model and evaluate
cnn_model.load_weights('best_model_datavalue.h5')

# Evaluate the model
loss, mae = cnn_model.evaluate(x_test, y_test)
print(f"Test Loss: {loss}")
print(f"Mean Absolute Error: {mae}")

# Optionally, visualize the predictions vs. actual values
predictions = cnn_model.predict(x_test)
for i in range(min(len(predictions), 10)):  # Visualize first 10 predictions
    print(f"Actual: {y_test[i]}, Predicted: {predictions[i]}")

for i in range(num_outputs):
    plt.figure(figsize=(10, 6))
    plt.scatter(range(len(y_test)), y_test[:, i], color='blue', label='Actual')
    plt.scatter(range(len(predictions)), predictions[:, i], color='red', label='Predicted', alpha=0.5)
    plt.title(f'Actual vs Predicted for Output {i+1}')
    plt.legend()
    plt.show()

# Calculate errors
errors = predictions - y_test

# Plotting the distribution of errors for each output
for i in range(num_outputs):
    plt.figure(figsize=(10, 6))
    sns.histplot(errors[:, i], kde=True)
    plt.title(f'Error Distribution for Output {i+1}')
    plt.xlabel('Error')
    plt.ylabel('Frequency')
    plt.show()

# When you need to use the scaler in the future
#scaler = joblib.load('minmax_scaler.joblib')
# Plot training and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()


# Scatter plot of actual vs. predicted values for each output
for i in range(num_outputs):
    plt.figure(figsize=(10, 6))
    plt.scatter(range(len(y_test)), y_test[:, i], color='blue', label='Actual')
    plt.scatter(range(len(predictions)), predictions[:, i], color='red', label='Predicted', alpha=0.5)
    plt.plot(range(len(predictions)), predictions[:, i], color='green', linestyle='--', label='Predicted Line')
    plt.title(f'Actual vs Predicted for Output {i+1}')
    plt.legend()
    plt.show()

# Calculate errors
errors = predictions - y_test

# Plotting the distribution of errors for each output
for i in range(num_outputs):
    plt.figure(figsize=(10, 6))
    sns.histplot(errors[:, i], kde=True)
    plt.title(f'Error Distribution for Output {i+1}')
    plt.xlabel('Error')
    plt.ylabel('Frequency')
    plt.show()
"""Test Loss: 2.950080394744873
Mean Absolute Error: 1.28671133518219"""
"""Test Loss: 1.977738618850708
Mean Absolute Error: 0.9539614915847778 """
'''Test Loss: 2.1319119930267334
Mean Absolute Error: 0.9866688251495361'''
''' Restnet top batch normalization 150 Test Loss: 1.8504526615142822
Mean Absolute Error: 0.890175461769104'''
'''resnet 256 Test Loss: 2.0185909271240234
Mean Absolute Error: 0.9425868391990662'''
'''180 with .005 lr Test Loss: 1.7148951292037964
Mean Absolute Error: 0.8585179448127747 better result with test data'''

''' 256 .005 Test Loss: 1.434592366218567
Mean Absolute Error: 0.8076307773590088'''
'''  256 .003 Test Loss: 1.3253782987594604
Mean Absolute Error: 0.7511170506477356'''

''' Test Loss: 1.2988651990890503
Mean Absolute Error: 0.7252750992774963  256 .006'''
''' Test Loss: 1.4156726598739624
Mean Absolute Error: 0.7940117120742798 256 .004'''
'''Test Loss: 1.65153968334198
Mean Absolute Error: 0.8239004015922546 150, 001, 004 more data'''

'''Test Loss: 1.398738980293274
Mean Absolute Error: 0.7464011311531067 .001, .006 180 more data'''
'''Test Loss: 1.3509056568145752
Mean Absolute Error: 0.7590972781181335 .001, .006 256 more data'''
'''.008 256 more data Test Loss: 1.3238434791564941
Mean Absolute Error: 0.761715829372406'''
"""Test Loss: 1.4795446395874023
Mean Absolute Error: 0.7930512428283691 RM optimisor .001 .09"""

"""with extra layers Test Loss: 1.2662584781646729
Mean Absolute Error: 0.7291149497032166"""

"""Test Loss: 1.2254701852798462
Mean Absolute Error: 0.6997698545455933 extra layers + deep """
"""Test Loss: 1.0248249769210815
Mean Absolute Error: 0.6392221450805664 with .03 dropout"""

"""Test Loss: 1.130457878112793
Mean Absolute Error: 0.6676424145698547 Average pooling an dabove codn"""

"""Test Loss: 1.161369800567627
Mean Absolute Error: 0.6815188527107239 avg above"""
"""Test Loss: 1.1105369329452515
Mean Absolute Error: 0.6752064824104309 avg below"""
"""Test Loss: 1.0892521142959595
Mean Absolute Error: 0.6663258075714111 with 256 in both conv layers"""

"""Test Loss: 0.29596543312072754
Mean Absolute Error: 0.3450961709022522 one cnv layer 1x layers"""
"""Test Loss: 0.6058049201965332
Mean Absolute Error: 0.475335955619812"""
# Out:
# Num GPUs Available:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 116
#     114 image_name = item['Image Name']
#     115 image_path = os.path.join(dataset_path3, image_name)
# --> 116 image = load_img(image_path, target_size=(256, 256))
#     117 image = img_to_array(image)
#     118 #image /= 255.0  # Normalize to [0, 1]
#     119 # Convert image data to uint8
#
# File ~/.local/lib/python3.10/site-packages/keras/src/utils/image_utils.py:439, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     437 elif color_mode == "rgb":
#     438     if img.mode != "RGB":
# --> 439         img = img.convert("RGB")
#     440 else:
#     441     raise ValueError('color_mode must be "grayscale", "rgb", or "rgba"')
#
# ...

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import joblib
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Activation
# Load the MinMaxScaler
scaler_filename = "minmax_scaler1.save"
scaler = joblib.load(scaler_filename)
# Define the custom swish activation function
def swish(x):
    return x * tf.sigmoid(x)

# Register the custom activation function globally
#tf.keras.utils.get_custom_objects()['swish'] = swish

model_regression = tf.keras.models.load_model('best_model_datavalue.h5')
# Load the trained model after registering the custom activation function
model_classification = tf.keras.models.load_model('best_model_classificationonly3.h5')
# Function to preprocess the image
def preprocess_image(image_path, target_size=(256, 256)):
    # Load and resize the image
    image = load_img(image_path, target_size=target_size)
    image = img_to_array(image)
    image = image.astype(np.uint8)
    return image
def preprocess_image1(image_path, target_size=(150, 150)):
    # Load and resize the image
    image = load_img(image_path, target_size=target_size)
    image = img_to_array(image)
    image = image.astype(np.uint8)
    return image
def predict_attributes(image_path):
    # Preprocess the image
    preprocessed_image = preprocess_image(image_path)
    preprocessed_image1 = preprocess_image1(image_path)
    
    # Add batch dimension
    preprocessed_image = np.expand_dims(preprocessed_image, axis=0)
    preprocessed_image1 = np.expand_dims(preprocessed_image1, axis=0)
    # Predict the attributes
    attribute_values = model_regression.predict(preprocessed_image)[0]  # Only attribute values without axes
    Predicted_axes = model_classification.predict(preprocessed_image1)[0]  # Only axes
    predicted_class = np.argmax(Predicted_axes)
    print(Predicted_axes)
    return attribute_values,predicted_class

# Path to the radar chart image for inference3radar_chart_path = "Test_images/2_mesial.png" #[6.5318923 5.6691446 3.9379337 0.5712681 0.5057521]
radar_chart_path = "Test_images/MER_Star_Plot.jpg" 
#radar_chart_path = "Test_images/1_potty.png"  # 3, 3.3314, 7.8154, 2.1419, 0, 0
#radar_chart_path = "Test_images/OIP.jpg"  # 5, 839.9671, 817.53, 784.5875, 997.4236, 510.8641 
#radar_chart_path = "Test_images/6_secondary.png"  # 5, 99.6905, 79.8694, 47.7971, 90.8473, 86.5432
#radar_chart_path = "Test_images/7_blotted_out.png"  # 3, 94.796, 98.604, 99.5643, 0, 0
#radar_chart_path = "Test_images/7_structural.png"
#radar_chart_path = "Test_images/2_mesial.png"
#radar_chart_path = "Test_images/radar_chart.jpg"
#radar_chart_path = "Test_images/radar_chart3_equi.png"
#radar_chart_path = "Test_images/radar_chart3.jpg"
#radar_chart_path = "Test_images/radar_chart5.jpg"
# Example usage
attribute_values, predicted_class= predict_attributes(radar_chart_path)

if predicted_class == 0:
    print("Number of Axes = 3")
    print(f"Attribute Values: {attribute_values[:3]}")
elif predicted_class == 1:
    print("Number of Axes = 5")
    print(f"Attribute Values: {attribute_values}")
else:
    print("Number of Axes is neither 3 nor 5")
# Display the preprocessed image
print(attribute_values)
plt.imshow(preprocess_image(radar_chart_path))
plt.axis('off')
plt.show()
# Out:
# ...
# 1/1 [==============================] - 1s 652ms/step
# [0.07895905 0.5279933  0.9041859 ]
# Number of Axes is neither 3 nor 5
# [8.294713  3.5165563 5.753249  3.3603027 4.806082 ]

# %%
import os
import json
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Input, Dropout, GlobalAveragePooling2D, Multiply,AveragePooling2D, MaxPooling2D,Conv2D,Add, Dense, Flatten,BatchNormalization, TimeDistributed, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import UpSampling2D, Cropping2D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

# Assuming each image is 256x256 pixels with 3 color channels (RGB)
input_shape = (150, 150, 3)
num_classes = 3  # 3 classes: 3 axes, 5 axes, Don't know

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Define dataset paths
dataset_path = r"extracted_data/FinalDatasetwithrangefix"
dataset_path1 = r"extracted_data/radarchart_with_linestar_4-6"
dataset_path2 = r"extracted_data/radarcharts_geridvaluesnofilllineentity2"
dataset_path3 = r"extracted_data/radarchart_with_linestar2"
dataset_path4 = r"extracted_data/radarcharts_geridvaluesdotentity6-10"
dataset_path5 = r"extracted_data/radarcharts_geridvaluesnofillboxentity6-10"
dataset_path6 = r"extracted_data/radarcharts_pygal_withfill6-10"
# Load metadata
with open(os.path.join(dataset_path, "metadata.json"), 'r') as json_file:
    metadata = json.load(json_file)['data']
with open(os.path.join(dataset_path1, "metadata.json"), 'r') as json_file:
    metadata1 = json.load(json_file)['data']
with open(os.path.join(dataset_path2, "metadata.json"), 'r') as json_file:
    metadata2 = json.load(json_file)['data']
with open(os.path.join(dataset_path3, "metadata.json"), 'r') as json_file:
    metadata3 = json.load(json_file)['data']
with open(os.path.join(dataset_path4, "metadata.json"), 'r') as json_file:
    metadata4 = json.load(json_file)['data']
with open(os.path.join(dataset_path5, "metadata.json"), 'r') as json_file:
    metadata5 = json.load(json_file)['data']
with open(os.path.join(dataset_path6, "metadata.json"), 'r') as json_file:
    metadata6 = json.load(json_file)['data']
# Initialize lists to store data and labels
data = []
labels = []

# Load and preprocess data and labels for the first dataset
for item in metadata:
    image_path = os.path.join(dataset_path, item['Image Name'])
    image = img_to_array(load_img(image_path, target_size=(150, 150)))
    data.append(image)
    num_axes = len(item['Attribute Data'])
    if num_axes == 3:
        label = 0  # Class 0 for 3 axes
    elif num_axes == 5:
        label = 1  # Class 1 for 5 axes
    else:
        label = 2  # Class 2 for Don't know
    labels.append(label)

# Load and preprocess data and labels for the second dataset
for item in metadata1:
    image_path = os.path.join(dataset_path1, item['Image Name'])
    image = img_to_array(load_img(image_path, target_size=(150, 150)))
    data.append(image)
    num_axes = len(item['Attribute Data'])
    if num_axes == 3:
        label = 0  # Class 0 for 3 axes
    elif num_axes == 5:
        label = 1  # Class 1 for 5 axes
    else:
        label = 2  # Class 2 for Don't know
    labels.append(label)
# Load and preprocess data and labels for the second dataset
for item in metadata2:
    image_path = os.path.join(dataset_path2, item['Image Name'])
    image = img_to_array(load_img(image_path, target_size=(150, 150)))
    data.append(image)
    num_axes = len(item['Attribute Data'])
    if num_axes == 3:
        label = 0  # Class 0 for 3 axes
    elif num_axes == 5:
        label = 1  # Class 1 for 5 axes
    else:
        label = 2  # Class 2 for Don't know
    labels.append(label)

"""for item in metadata3:
    image_path = os.path.join(dataset_path3, item['Image Name'])
    image = img_to_array(load_img(image_path, target_size=(150, 150)))
    data.append(image)
    num_axes = len(item['Attribute Data'])
    if num_axes == 3:
        label = 0  # Class 0 for 3 axes
    elif num_axes == 5:
        label = 1  # Class 1 for 5 axes
    else:
        label = 2  # Class 2 for Don't know
    labels.append(label)"""
for item in metadata4:
    image_path = os.path.join(dataset_path4, item['Image Name'])
    image = img_to_array(load_img(image_path, target_size=(150, 150)))
    data.append(image)
    num_axes = len(item['Attribute Data'])
    if num_axes == 3:
        label = 0  # Class 0 for 3 axes
    elif num_axes == 5:
        label = 1  # Class 1 for 5 axes
    else:
        label = 2  # Class 2 for Don't know
    labels.append(label)
"""for item in metadata5:
    image_path = os.path.join(dataset_path5, item['Image Name'])
    image = img_to_array(load_img(image_path, target_size=(150, 150)))
    data.append(image)
    num_axes = len(item['Attribute Data'])
    if num_axes == 3:
        label = 0  # Class 0 for 3 axes
    elif num_axes == 5:
        label = 1  # Class 1 for 5 axes
    else:
        label = 2  # Class 2 for Don't know
    labels.append(label)"""
for item in metadata6:
    image_path = os.path.join(dataset_path6, item['Image Name'])
    image = img_to_array(load_img(image_path, target_size=(150, 150)))
    data.append(image)
    num_axes = len(item['Attribute Data'])
    if num_axes == 3:
        label = 0  # Class 0 for 3 axes
    elif num_axes == 5:
        label = 1  # Class 1 for 5 axes
    else:
        label = 2  # Class 2 for Don't know
    labels.append(label)
# Convert lists to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Split the dataset into training, validation, and testing sets
x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.67, random_state=42)

# Class weights
#class_weights = {0: 2.0, 1: 2.0, 2: 1.0}  # More weight to classes 0 and 1
# Check the length of data and labels
print(f"Length of data: {len(data)}")
print(f"Length of labels: {len(labels)}")  # Corrected from preprocessed_labels to labels
# Check the shapes of the splits
print(f"Training data shape: {x_train.shape}")
print(f"Testing data shape: {x_test.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Testing labels shape: {y_test.shape}")

# Build the ResNet50 model with attention mechanism
def create_attention_module(feature_map, input_channels, ratio=8):
    squeeze = GlobalAveragePooling2D()(feature_map)
    excitation = Dense(units=input_channels // ratio, activation='relu')(squeeze)
    excitation = Dense(units=input_channels, activation='sigmoid')(excitation)
    excitation = tf.reshape(excitation, [-1, 1, 1, input_channels])
    scale = Multiply()([feature_map, excitation])
    return scale

def build_cnn_with_attention(input_shape, num_classes):
    base_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False

    last_conv_layer = base_model.get_layer('block5_conv3').output
    conv_layer = Conv2D(2048, (1, 1), activation='relu', padding='same')(last_conv_layer)
    attention_layer = create_attention_module(last_conv_layer, input_channels=2048)
    residual_layer = tf.keras.layers.Add()([conv_layer, attention_layer])

    gap_layer = GlobalAveragePooling2D()(residual_layer)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(gap_layer)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)


    output = Dense(num_classes, activation='softmax')(x)  # Output layer with softmax activation

    model = Model(inputs=base_model.input, outputs=output)

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Build the model
cnn_model = build_cnn_with_attention(input_shape, num_classes)

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
model_checkpoint = ModelCheckpoint('best_model_classificationonly.h5', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.006)
tensorboard = TensorBoard(log_dir='./logs')

# Summary of the model
cnn_model.summary()

# Fit the model for classification
history_classification = cnn_model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=100,
    batch_size=16,
    callbacks=[early_stopping, model_checkpoint, reduce_lr, tensorboard],
    #class_weight=class_weights  # Use class weights during training
)

# Load best model weights
cnn_model.load_weights('best_model_classificationonly.h5')

# Evaluate the model for classification
loss_classification, accuracy_classification = cnn_model.evaluate(x_test, y_test)

print(f"Test Classification Loss: {loss_classification}")
print(f"Test Classification Accuracy: {accuracy_classification}")

# Optionally, visualize the predictions vs. actual values for classification
classification_predictions = np.argmax(cnn_model.predict(x_test), axis=1)

# Visualize classification predictions
for i in range(min(len(classification_predictions), 10)):  # Visualize first 10 predictions
    print(f"Actual Classification: {y_test[i]}, Predicted Classification: {classification_predictions[i]}")
    
'''Test Classification Loss: 0.02307920902967453
Test Classification Accuracy: 0.9996172785758972'''

'''Test Classification Loss: 0.01899619773030281
Test Classification Accuracy: 1.0 no weights .005 learning rate'''
'''Test Classification Loss: 0.0077088563703000546
Test Classification Accuracy: 1.0 .006 learning rate'''

'''Test Classification Loss: 0.015353894792497158
Test Classification Accuracy: 0.9986733198165894 dataaset 1 and 2 .006
'''
'''Test Classification Loss: 0.0072157480753958225
Test Classification Accuracy: 1.0 dataset 3$4'''
# Out:
# Num GPUs Available:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 52
#      50 for item in metadata:
#      51     image_path = os.path.join(dataset_path, item['Image Name'])
# ---> 52     image = img_to_array(load_img(image_path, target_size=(150, 150)))
#      53     data.append(image)
#      54     num_axes = len(item['Attribute Data'])
#
# File ~/.local/lib/python3.10/site-packages/keras/src/utils/image_utils.py:423, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     421         path = str(path.resolve())
#     422     with open(path, "rb") as f:
# --> 423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#     425     raise TypeError(
#     426         f"path should be path-like or io.BytesIO, not {type(path)}"
#     427     )
#
# KeyboardInterrupt:

# %%
import os
import json
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Input, Dropout, GlobalAveragePooling2D, Multiply,AveragePooling2D, MaxPooling2D,Conv2D,Add, Dense, Flatten,BatchNormalization, TimeDistributed, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import UpSampling2D, Cropping2D
from tensorflow.keras.applications import ResNet50,VGG19
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Assuming each image is 256x256 pixels with 3 color channels (RGB)
input_shape = (150, 150, 3)
num_classes = 3  # 3 classes: 3 axes, 5 axes, Don't know

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Define dataset paths
dataset_paths = [
    r"extracted_data/FinalDatasetwithrangefix",
    r"extracted_data/radarchart_with_linestar_4-6",
    r"extracted_data/radarcharts_geridvaluesnofilllineentity2",
    r"extracted_data/radarchart_with_linestar2",
    r"extracted_data/radarcharts_geridvaluesdotentity6-10",
    r"extracted_data/radarcharts_geridvaluesnofillboxentity6-10",
    r"extracted_data/radarcharts_pygal_withfill6-10"
]

# Define an ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=20,      # Rotate images randomly up to 20 degrees
    width_shift_range=0.1,  # Shift images horizontally by up to 10% of the width
    height_shift_range=0.1, # Shift images vertically by up to 10% of the height
    shear_range=0.2,        # Apply shear transformation with intensity up to 20%
    zoom_range=0.2,         # Zoom images randomly by up to 20%
    horizontal_flip=True,   # Flip images horizontally
    vertical_flip=True,     # Flip images vertically
    fill_mode='nearest'     # Fill in missing pixels using the nearest value
)

# Build the ResNet50 model with attention mechanism
def create_attention_module(feature_map, input_channels, ratio=8):
    squeeze = GlobalAveragePooling2D()(feature_map)
    excitation = Dense(units=input_channels // ratio, activation='relu')(squeeze)
    excitation = Dense(units=input_channels, activation='sigmoid')(excitation)
    excitation = tf.reshape(excitation, [-1, 1, 1, input_channels])
    scale = Multiply()([feature_map, excitation])
    return scale

def build_cnn_with_attention(input_shape, num_classes):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False

    last_conv_layer = base_model.get_layer('conv5_block3_out').output
    conv_layer = Conv2D(2048, (1, 1), activation='relu', padding='same')(last_conv_layer)
    attention_layer = create_attention_module(last_conv_layer, input_channels=2048)
    residual_layer = tf.keras.layers.Add()([conv_layer, attention_layer])

    gap_layer = GlobalAveragePooling2D()(residual_layer)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(gap_layer)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    output = Dense(num_classes, activation='softmax')(x)  # Output layer with softmax activation

    model = Model(inputs=base_model.input, outputs=output)

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Iterate over each dataset path
for dataset_path in dataset_paths:
    # Load metadata
    with open(os.path.join(dataset_path, "metadata.json"), 'r') as json_file:
        metadata = json.load(json_file)['data']

    # Initialize lists to store data and labels
    data = []
    labels = []

    # Load and preprocess data and labels
    for item in metadata:
        image_path = os.path.join(dataset_path, item['Image Name'])
        image = img_to_array(load_img(image_path, target_size=(150, 150)))
        data.append(image)
        num_axes = len(item['Attribute Data'])
        if num_axes == 3:
            label = 0  # Class 0 for 3 axes
        elif num_axes == 5:
            label = 1  # Class 1 for 5 axes
        else:
            label = 2  # Class 2 for Don't know
        labels.append(label)

    # Convert lists to numpy arrays
    data = np.array(data)
    labels = np.array(labels)

    # Split the dataset into training, validation, and testing sets
    x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
    x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.67, random_state=42)

    # Fit the data augmentation parameters to your training data
    datagen.fit(x_train)

    # Build the model
    cnn_model = build_cnn_with_attention(input_shape, num_classes)

    # Callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)
    model_checkpoint = ModelCheckpoint('best_model_classificationonly.h5', save_best_only=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.006)
    tensorboard = TensorBoard(log_dir='./logs')

    # Summary of the model
    cnn_model.summary()

    # Fit the model for classification with data augmentation
    history_classification = cnn_model.fit(
        datagen.flow(x_train, y_train, batch_size=16),
        validation_data=(x_val, y_val),
        epochs=100,
        steps_per_epoch=len(x_train) / 16,  # Number of batches per epoch
        callbacks=[early_stopping, model_checkpoint, reduce_lr, tensorboard]
    )

    # Load best model weights
    cnn_model.load_weights('best_model_classificationonly.h5')

    # Evaluate the model for classification
    loss_classification, accuracy_classification = cnn_model.evaluate(x_test, y_test)

    print(f"Test Classification Loss for dataset {dataset_path}: {loss_classification}")
    print(f"Test Classification Accuracy for dataset {dataset_path}: {accuracy_classification}")

    # Optionally, visualize the predictions vs. actual values for classification
    classification_predictions = np.argmax(cnn_model.predict(x_test), axis=1)

    # Visualize classification predictions
    for i in range(min(len(classification_predictions), 10)):  # Visualize first 10 predictions
        print(f"Actual Classification: {y_test[i]}, Predicted Classification: {classification_predictions[i]}")
# Out:
# 2024-04-19 14:57:12.563582: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-19 14:57:12.594264: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-19 14:57:12.594296: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-19 14:57:12.595238: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import os
import json
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Input, Dropout, GlobalAveragePooling2D, Multiply,AveragePooling2D, MaxPooling2D,Conv2D,Add, SeparableConv2D, Dense, Flatten,BatchNormalization, TimeDistributed, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import UpSampling2D, Cropping2D
from tensorflow.keras.applications import ResNet50,VGG19
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler,TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.activations import selu
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.losses import KLDivergence
# Assuming each image is 256x256 pixels with 3 color channels (RGB)
input_shape = (150, 150, 3)
num_classes = 3  # 3 classes: 3 axes, 5 axes, Don't know

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Define dataset paths
dataset_paths = [
    r"extracted_data/FinalDatasetwithrangefix",
    r"extracted_data/radarcharts_geridvaluesnofilllineentity2",
     r"extracted_data/radarchart_with_linestar_4-6",
    r"extracted_data/radarchart_with_linestar2",
    r"extracted_data/radarcharts_equilateral",
    r"extracted_data/radarcharts_only3_nofill",
    r"extracted_data/radarcharts_geridvaluesnofillboxentity6-10",
    r"extracted_data/radarchart_with_linestar3"
]

# Initialize lists to store data and labels
data = []
labels = []

# Load metadata and preprocess data and labels
for dataset_path in dataset_paths:
    with open(os.path.join(dataset_path, "metadata.json"), 'r') as json_file:
        metadata = json.load(json_file)['data']

    for item in metadata:
        image_path = os.path.join(dataset_path, item['Image Name'])
        image = img_to_array(load_img(image_path, target_size=(150, 150)))
        data.append(image)
        num_axes = len(item['Attribute Data'])
        if num_axes == 3:
            label = 0  # Class 0 for 3 axes
        elif num_axes == 5:
            label = 1  # Class 1 for 5 axes
        else:
            label=2 # Class 2 for Don't know
        labels.append(label)

# Convert lists to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Split the combined dataset into training, validation, and testing sets
x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.67, random_state=42)

# Check the length of data and labels
print(f"Length of data: {len(data)}")
print(f"Length of labels: {len(labels)}")  # Corrected from preprocessed_labels to labels
# Check the shapes of the splits
print(f"Training data shape: {x_train.shape}")
print(f"Testing data shape: {x_test.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Testing labels shape: {y_test.shape}")
# Define an ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=45,      # Rotate images randomly up to 20 degrees
    width_shift_range=0.1,  # Shift images horizontally by up to 10% of the width
    height_shift_range=0.1, # Shift images vertically by up to 10% of the height
    shear_range=0.2,        # Apply shear transformation with intensity up to 20%
    zoom_range=0.2,         # Zoom images randomly by up to 20%
    horizontal_flip=True,   # Flip images horizontally
    vertical_flip=True,     # Flip images vertically
    fill_mode='nearest'     # Fill in missing pixels using the nearest value
)


# Build the ResNet50 model with attention mechanism
def create_attention_module(feature_map, input_channels, ratio=8):
    squeeze = GlobalAveragePooling2D()(feature_map)
    excitation = Dense(units=input_channels // ratio, activation='relu')(squeeze)
    excitation = Dense(units=input_channels, activation='sigmoid')(excitation)
    excitation = tf.reshape(excitation, [-1, 1, 1, input_channels])
    scale = Multiply()([feature_map, excitation])
    return scale
# Define the attention mechanism variant
def create_multihead_attention(feature_map, num_heads=4):
    multihead_attention = MultiHeadAttention(num_heads=num_heads)(feature_map, feature_map)
    return multihead_attention
    
def build_cnn_with_attention(input_shape, num_classes):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False

    last_conv_layer = BatchNormalization()(base_model.output)
     # Dilated Convolution
    dilated_conv = Conv2D(filters=1024, kernel_size=(3, 3), activation='relu', padding='same', dilation_rate=2)(last_conv_layer)
    conv_layer = BatchNormalization()(dilated_conv )
    # Pooling
    conv_layer = MaxPooling2D((2, 2))(conv_layer)
    dilated_conv = Conv2D(filters=2048, kernel_size=(3, 3), activation='relu', padding='same', dilation_rate=2)(conv_layer)
    conv_layer1 = BatchNormalization()(dilated_conv)
    conv_layer = MaxPooling2D((2, 2))( conv_layer1)

    #attention_output = create_multihead_attention(conv_layer1)
    attention_layer = create_attention_module(conv_layer, input_channels=2048)
    residual_layer = tf.keras.layers.Add()([ conv_layer , attention_layer])

    gap_layer = GlobalAveragePooling2D()(residual_layer)
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.01))(gap_layer)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    output = Dense(num_classes, activation='sigmoid')(x)  # Output layer with softmax activation

    model = Model(inputs=base_model.input, outputs=output)

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Build the model
cnn_model = build_cnn_with_attention(input_shape, num_classes)

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
model_checkpoint = ModelCheckpoint('best_model_classificationonly3.h5', save_best_only=True)
#reduce_lr = LearningRateScheduler(lr_schedule)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.006)
tensorboard = TensorBoard(log_dir='./logs')

# Summary of the model
cnn_model.summary()

# Fit the model for classification with data augmentation
history_classification = cnn_model.fit(
    datagen.flow(x_train, y_train, batch_size=16),
    validation_data=(x_val, y_val),
    epochs=100,
    steps_per_epoch=len(x_train) / 16,  # Number of batches per epoch
    callbacks=[early_stopping, model_checkpoint, reduce_lr, tensorboard]
)

# Load best model weights
cnn_model.load_weights('best_model_classificationonly3.h5')
# Evaluate the model on the combined testing set
loss, accuracy = cnn_model.evaluate(x_test, y_test)

print(f"Overall Test Loss: {loss}")
print(f"Overall Test Accuracy: {accuracy}")
"""Overall Test Loss: 0.1532704085111618
Overall Test Accuracy: 0.9950261116027832 only oip and 3 eval one selu"""
# Out:
# 2024-04-22 12:44:42.151597: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-22 12:44:42.678775: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 12:44:42.678823: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-22 12:44:42.801641: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
